# %%
data = [20,12,52,32,62,52,34,25,36]

# %%
data
# Out:
# [20, 12, 52, 32, 62, 52, 34, 25, 36]

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# [20, 12, 52, 32, 62, 52, 34, 25, 36]

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()
data_copy
# Out:
# [12, 20, 25, 32, 34, 36, 52, 52, 62]

# %%
data_copy.append(179)

# %%
data_copy.append(290)

# %%
data_copy.append(200)

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
del data_copy

# %%
data_copy = data
data
# Out:
# [20, 12, 52, 32, 62, 52, 34, 25, 36]

# %%
data_copy.append(210)
data_copy
# Out:
# [20, 12, 52, 32, 62, 52, 34, 25, 36, 210, 210]

# %%
del data_copy[9:11]

# %%
data_copy
# Out:
# [20, 12, 52, 32, 62, 52, 34, 25, 36]

# %%
data_copy2 = data_copy

# %%
data_copy2.insert(0,0)

# %%
data_copy2.insert(1,-5)

# %%
data_copy2
# Out:
# [0, -5, 20, 12, 52, 32, 1, 1, 62, 52, 34, 25, 36]

# %%
del data_copy2[6:8]

# %%
data_copy2.insert(1,-50)

# %%
sns.histplot(data_copy2,kde=True) #left skewed
# Out:
# <Axes: ylabel='Count'>

# %%
import numpy as np
mean = .5
std = .2
normal_data = np.random.normal(mean,std,1000)
normal_data
# Out:
# array([ 0.78519465,  0.71878041,  0.19029218,  0.13649488,  0.25964169,
#         0.20038941,  0.12856783,  0.23052665,  0.20072003,  0.61331968,
#         0.24679227,  0.16344815,  0.36522273,  0.49768864,  0.20043251,
#         0.52512903,  0.49328432,  0.47024862,  0.0567686 ,  0.47196246,
#         0.57278907,  0.78639912,  0.41687221,  0.91603629,  0.4449332 ,
#         0.57286873,  0.46264932,  0.30835152,  0.72860488,  0.56626781,
#         0.44397979,  0.19887307,  0.65565126,  0.50998645,  0.45760457,
#         0.38353901,  0.5276851 , -0.04963573,  0.49848624,  0.24099696,
#         0.38344661,  0.28059434,  0.19133479,  0.53154249,  0.25166361,
#         0.29994498,  0.50778705,  0.60438919,  0.20041443,  0.27110353,
#         0.42814166,  0.48147839,  0.5141357 ,  0.27412685,  0.15659799,
#         0.32949383,  0.57106774,  0.44638545,  0.71642837,  0.41561796,
#         0.47344879,  0.62158484,  0.23160457,  0.47763254,  0.89143953,
# ...

# %%
sns.histplot(normal_data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
mean = 0
std = 1

lognormal_data = np.random.lognormal(mean,std,1000)
lognormal_data
# Out:
# array([2.21061453e-01, 4.21256907e-01, 8.58467333e-01, 7.31754330e+00,
#        1.53442997e+00, 7.92064195e-01, 1.39897627e+00, 1.88434917e+00,
#        6.11651208e-01, 6.83605118e-01, 2.23931464e-01, 9.98890378e-01,
#        2.37774538e-01, 5.62625361e-01, 1.05486347e+00, 2.80348214e+00,
#        7.27209308e-01, 8.11861428e-01, 2.09760280e+00, 5.73378740e+00,
#        1.23418549e+00, 1.00805355e+00, 2.56351958e+00, 5.15260991e-01,
#        1.03994743e+00, 2.06672224e+00, 1.06238330e+00, 1.54548010e+00,
#        1.61646285e+00, 1.04120876e+00, 7.01958426e-01, 4.59658998e-01,
#        1.56213952e+00, 9.03975294e-01, 1.08985516e+00, 3.56965059e-01,
#        1.27404451e+00, 9.95770357e+00, 4.29216904e-01, 1.47484912e+01,
#        1.46046546e+00, 6.41475024e-01, 8.66568737e-02, 3.03240242e-01,
#        5.32874477e-01, 2.07922954e+00, 5.64538119e-01, 2.87125919e+00,
#        1.83513147e+00, 3.39239246e+00, 3.42122397e+00, 1.14481248e+00,
# ...

# %%
sns.histplot(lognormal_data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(lognormal_data),kde=True)
# Out:
# <Axes: ylabel='Count'>
